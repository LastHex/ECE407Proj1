# %% [markdown]
# # Progress Report

# %% [markdown]
# ### Load the ECG File

# %%
#Show plots in the notebook
# %matplotlib inline
import sys
sys.path.append('..')
import patient

# Point to the appropriate ECG file
filename = '../../../9004.ecg'

# Create the patient object
p = patient.Patient()

# Read the file
p.load_ecg_data(filename)
# Out:
# Reading filename (header and data): ../../../9004.ecg

# %% [markdown]
# ### Plot Leads

# %%
p.plot_leads(0)
# Out:
# Plotting lead: 0

# %%
p.plot_leads(1)
# Out:
# Plotting lead: 1

# %%
p.plot_leads(2)
# Out:
# Plotting lead: 2

# %% [markdown]
# ### Compute $\frac{df}{dx}$ on the CPU - Lead 0

# %%
p.compute_derivative_gpu(0)

# %% [markdown]
# ### Compute $\frac{df}{dx}$ on the CPU - Lead 1

# %%
p.compute_derivative_gpu(1)

# %% [markdown]
# ### Compute $\frac{df}{dx}$ on the CPU - Lead 2

# %%
p.compute_derivative_gpu(2)

# %% [markdown]
# ### Sorted Plots

# %%
p.compute_derivative_gpu_s(0)

# %%
p.compute_derivative_gpu_s(1)

# %%
p.compute_derivative_gpu_s(2)

# %%
p.plot_leads_s()
# Out:
# No lead number or list provided, defaulting to plot all...
# Plotting lead: 0
# Plotting lead: 1
# Plotting lead: 2
