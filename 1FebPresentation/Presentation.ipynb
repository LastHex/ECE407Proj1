# %% [markdown]
# # Progress Report

# %% [markdown]
# ### Load the ECG File

# %%
#Show plots in the notebook
# %matplotlib inline
import sys
sys.path.append('..')
import patient

# Point to the appropriate ECG file
filename = r'C:\Users\Sam\9004.ecg'

# Create the patient object
p = patient.Patient()

# Read the file
p.load_ecg_data(filename)
# Out:
# Reading filename (header and data): C:\Users\Sam\9004.ecg

# %% [markdown]
# ### Plot Lead 0

# %%
# Plot the file
p.plot_leads(0)
# Out:
# Plotting lead: 0

# %% [markdown]
# ### Compute $\frac{df}{dx}$ on the CPU - Lead 0

# %%
p.compute_derivative_gpu(0)
